# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data_set = pd.read_csv("heart.csv")
data_set.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data_set.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
fig = plt.figure(figsize =(25,15))
sb.heatmap(data_set.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
rel_data_set = data_set.iloc[:,[0,1,2,6,7,10,13]]
rel_data_set.head()
# Out:
#    age  sex  cp  restecg  thalach  slope  target
# 0   52    1   0        1      168      2       0
# 1   53    1   0        0      155      0       0
# 2   70    1   0        1      125      0       0
# 3   61    1   0        1      161      2       0
# 4   62    0   0        1      106      1       0

# %%
rel_data_set['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
rel_data_set['thalach'].value_counts()
# Out:
# 162    35
# 160    31
# 163    29
# 173    28
# 152    28
#        ..
# 194     3
# 185     3
# 106     3
# 88      3
# 113     3
# Name: thalach, Length: 91, dtype: int64

# %%
plt.figure(figsize=(5,5))
sb.countplot(x=rel_data_set['sex'],hue=rel_data_set['target'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(5,5))
sb.countplot(x=rel_data_set['slope'],hue=rel_data_set['target'])
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
plt.figure(figsize=(5,5))
sb.countplot(x=rel_data_set['cp'],hue=rel_data_set['target'])
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
plt.figure(figsize=(35,5))
sb.countplot(x=rel_data_set['thalach'],hue=rel_data_set['target'])
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='count'>
